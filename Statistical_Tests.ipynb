# %%
### The required libraries and packages ###
import os 
import networkx as nx
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
folder_path = "data/"
FA_path = "FA_matrices_c/"
GM_path = "GM_matrices_c/"
fMRI_path = "fMRI_matrices_c/"

# %%
names = pd.read_csv(folder_path + "mindboggle_ROIs.txt", sep = "\t" )
name_list = names.iloc[:, 0].tolist()

# %%
clinical_data = pd.read_csv(folder_path + "clinic.csv", index_col = 1)
cols_to_keep = ["age", "sex", "dd", "edss", "controls_ms"]
clinical_data = clinical_data[cols_to_keep]

# %%
def load_data(matrices_path):
    # We obtain all files names and filter for csv
    all_files = os.listdir(folder_path + matrices_path)
    csv_files = [file for file in all_files if file.endswith('.csv')]
    
    # Depending on which matrices we import we have diferent "endnames"
    if matrices_path == FA_path:
        to_split ="_FA_factor_corrected.csv"
    elif matrices_path == GM_path:
        to_split = "_GM_matrix_corrected.csv"
    elif matrices_path == fMRI_path:
        to_split = "_r_matrix_corrected.csv"

    # Create a dictionary
    #### keys are subjects ids, obtained from splitting file name
    #### values are each dataframe
    #### column names are nodes names
    dfs = {file.split(to_split)[0]: pd.read_csv(os.path.join(folder_path, matrices_path,file), header = None, names = name_list) 
          for file in csv_files}
    
    # Set dataframes index as nodes names
    for key, df in dfs.items():
        df.index = name_list
    
    # Create a list to store the upper triangular elements as dictionaries
    upper_triangular_dicts = []

    # Iterate through the dictionary and extract the upper triangular elements
    for key, df in dfs.items():
        n = len(df)
        upper_triangular_data = {}

        for i in range(n):
            for j in range(i+1, n):  # j must be > i in order to iterate over upper diagonal, we skip diagonal
                row_name = df.index[i] 
                col_name = df.columns[j]
                combined_name = f"{row_name}/{col_name}" # Create columns name as combination of nodes, i.e. connection 
                value = df.iloc[i, j]
                upper_triangular_data[combined_name] = value # Add value to dictionary

    # Add the upper triangular dictionary to the list
        upper_triangular_dicts.append(upper_triangular_data)

    # Convert the list of dictionaries to a DataFrame
    result = pd.DataFrame(upper_triangular_dicts, index=dfs.keys())
    df_final =pd.concat([result, clinical_data], axis = 1) # Merge with clinical data
    
    return(df_final)

# %%
FA_df = load_data(FA_path)
FA_df.head()
# Out:
#           ctx-lh-caudalanteriorcingulate/ctx-lh-caudalmiddlefrontal  \
# 002MSVIS                                           0.422862
# 003MSVIS                                           0.360946
# 004MSVIS                                           0.452194
# 005MSVIS                                           0.395634
# 010MSVIS                                           0.381513
#
#           ctx-lh-caudalanteriorcingulate/ctx-lh-cuneus  \
# 002MSVIS                                           0.0
# 003MSVIS                                           0.0
# 004MSVIS                                           0.0
# 005MSVIS                                           0.0
# 010MSVIS                                           0.0
#
#           ctx-lh-caudalanteriorcingulate/ctx-lh-entorhinal  \
# 002MSVIS                                               0.0
# 003MSVIS                                               0.0
# 004MSVIS                                               0.0
# 005MSVIS                                               0.0
# 010MSVIS                                               0.0
#
#           ctx-lh-caudalanteriorcingulate/ctx-lh-fusiform  \
# 002MSVIS                                             0.0
# 003MSVIS                                             0.0
# 004MSVIS                                             0.0
# 005MSVIS                                             0.0
# 010MSVIS                                             0.0
#
#           ctx-lh-caudalanteriorcingulate/ctx-lh-inferiorparietal  \
# 002MSVIS                                           0.374716
# 003MSVIS                                           0.346052
# 004MSVIS                                           0.390203
# 005MSVIS                                           0.405738
# 010MSVIS                                           0.385011
#
#           ctx-lh-caudalanteriorcingulate/ctx-lh-inferiortemporal  \
# 002MSVIS                                           0.344459
# 003MSVIS                                           0.285988
# 004MSVIS                                           0.000000
# 005MSVIS                                           0.363048
# 010MSVIS                                           0.344250
#
#           ctx-lh-caudalanteriorcingulate/ctx-lh-isthmuscingulate  \
# 002MSVIS                                           0.502935
# 003MSVIS                                           0.467187
# 004MSVIS                                           0.504437
# 005MSVIS                                           0.488313
# 010MSVIS                                           0.462187
#
#           ctx-lh-caudalanteriorcingulate/ctx-lh-lateraloccipital  \
# 002MSVIS                                           0.000000
# 003MSVIS                                           0.258432
# 004MSVIS                                           0.330954
# 005MSVIS                                           0.321842
# 010MSVIS                                           0.000000
#
#           ctx-lh-caudalanteriorcingulate/ctx-lh-lateralorbitofrontal  \
# 002MSVIS                                           0.383026
# 003MSVIS                                           0.376243
# 004MSVIS                                           0.408644
# 005MSVIS                                           0.339294
# 010MSVIS                                           0.390884
#
#           ctx-lh-caudalanteriorcingulate/ctx-lh-lingual  ...  \
# 002MSVIS                                       0.000000  ...
# 003MSVIS                                       0.000000  ...
# 004MSVIS                                       0.000000  ...
# 005MSVIS                                       0.005412  ...
# 010MSVIS                                       0.000000  ...
#
#           ctx-rh-superiortemporal/ctx-rh-transversetemporal  \
# 002MSVIS                                           0.354605
# 003MSVIS                                           0.330118
# 004MSVIS                                           0.322964
# 005MSVIS                                           0.354825
# 010MSVIS                                           0.300334
#
#           ctx-rh-superiortemporal/ctx-rh-insula  \
# 002MSVIS                               0.401124
# 003MSVIS                               0.377220
# 004MSVIS                               0.381072
# 005MSVIS                               0.412469
# 010MSVIS                               0.354225
#
#           ctx-rh-supramarginal/ctx-rh-transversetemporal  \
# 002MSVIS                                        0.383299
# 003MSVIS                                        0.358125
# 004MSVIS                                        0.390045
# 005MSVIS                                        0.450964
# 010MSVIS                                        0.380448
#
#           ctx-rh-supramarginal/ctx-rh-insula  \
# 002MSVIS                            0.373590
# 003MSVIS                            0.352559
# 004MSVIS                            0.391322
# 005MSVIS                            0.422590
# 010MSVIS                            0.372597
#
#           ctx-rh-transversetemporal/ctx-rh-insula    age  sex     dd  edss  \
# 002MSVIS                                 0.366205  51.53    1  22.18   7.5
# 003MSVIS                                 0.360763  58.06    0   9.57   6.0
# 004MSVIS                                 0.372827  60.78    1   6.79   3.0
# 005MSVIS                                 0.392626  37.95    0   8.45   1.5
# 010MSVIS                                 0.362986  52.64    0   9.05   2.0
#
#           controls_ms
# 002MSVIS            1
# 003MSVIS            1
# 004MSVIS            1
# 005MSVIS            1
# 010MSVIS            1
#
# [5 rows x 2855 columns]

# %%
# Statistics
from scipy.stats import mannwhitneyu, ttest_ind, bartlett, shapiro
from statsmodels.stats.multitest import multipletests

# %%
import warnings
warnings.filterwarnings('ignore')

#Creation of empty dataframe to stro values
connection_stats = pd.DataFrame(columns = ["ROI", "pvalue"])
alpha = 0.05
features = FA_df.iloc[:, :-6].columns.to_list() #Remove clinical data columns and convert lo list

#Divide our dataset into HS and PwMS to check normality
HS = FA_df.loc[FA_df["controls_ms"] == 0, :]
PwMS = FA_df.loc[FA_df["controls_ms"] == 1, :]

for feat in features:
    # Check normality with Shapiro
    stat1, p1 = shapiro(HS[feat])
    stat2, p2 = shapiro(PwMS[feat])

    if (p1 > alpha) and (p2 > alpha): 

        #Check homoscedasticity to include it in test
        stat_b, p_b = bartlett(HS[feat], PwMS[feat])
        hom = True
        if p_b <= alpha:
            hom = False
        
        #If it meets conditions it is normal
        
        stat, p = ttest_ind(HS[feat], PwMS[feat], equal_var = hom)
        
    else:
        # When it is not normal
        stat,p = mannwhitneyu(HS[feat], PwMS[feat])
        
    if p <= alpha:
        new_row =pd.DataFrame({"ROI": [feat], "pvalue": [p]})
        connection_stats = pd.concat([connection_stats, new_row], ignore_index = True)  
    
# Add Bonferroni correction

bonf = multipletests(connection_stats["pvalue"], method = "bonferroni")
connection_stats["p_bonf"] = bonf[1]
# New dataframe only with ROIs that pass the test
df_bonf = connection_stats[connection_stats["p_bonf"] < alpha]
# keep a list of columns  (ROIs) that pass the test
stat_cols = df_bonf["ROI"].tolist()

# %%
#Create final dataframes
passed_df = FA_df[stat_cols]
clinical_data = FA_df[cols_to_keep] ##REMEMBER WE HAVE THESE COLUMS FROM PREVIOUS CELL

final_df = pd.concat([passed_df, clinical_data], axis = 1)
final_df
# Out:
#           ctx-lh-caudalanteriorcingulate/Left-Caudate  \
# 002MSVIS                                     0.384047
# 003MSVIS                                     0.307005
# 004MSVIS                                     0.353240
# 005MSVIS                                     0.392988
# 010MSVIS                                     0.381108
# ...                                               ...
# sFIS_04                                      0.398784
# sFIS_05                                      0.401528
# sFIS_06                                      0.413560
# sFIS_07                                      0.433221
# sFIS_09                                      0.408060
#
#           ctx-lh-caudalanteriorcingulate/ctx-rh-caudalmiddlefrontal  \
# 002MSVIS                                           0.489209
# 003MSVIS                                           0.440887
# 004MSVIS                                           0.539666
# 005MSVIS                                           0.480349
# 010MSVIS                                           0.464374
# ...                                                     ...
# sFIS_04                                            0.542326
# sFIS_05                                            0.514213
# sFIS_06                                            0.559308
# sFIS_07                                            0.537874
# sFIS_09                                            0.549898
#
#           ctx-lh-caudalanteriorcingulate/ctx-rh-rostralmiddlefrontal  \
# 002MSVIS                                           0.446729
# 003MSVIS                                           0.426359
# 004MSVIS                                           0.518063
# 005MSVIS                                           0.455465
# 010MSVIS                                           0.459644
# ...                                                     ...
# sFIS_04                                            0.500175
# sFIS_05                                            0.505240
# sFIS_06                                            0.533745
# sFIS_07                                            0.521213
# sFIS_09                                            0.524115
#
#           ctx-lh-caudalmiddlefrontal/ctx-rh-paracentral  \
# 002MSVIS                                       0.524677
# 003MSVIS                                       0.475393
# 004MSVIS                                       0.552257
# 005MSVIS                                       0.550401
# 010MSVIS                                       0.472687
# ...                                                 ...
# sFIS_04                                        0.557633
# sFIS_05                                        0.563031
# sFIS_06                                        0.608780
# sFIS_07                                        0.559301
# sFIS_09                                        0.598555
#
#           ctx-lh-cuneus/ctx-lh-inferiortemporal  \
# 002MSVIS                               0.426897
# 003MSVIS                               0.433756
# 004MSVIS                               0.485544
# 005MSVIS                               0.462872
# 010MSVIS                               0.473701
# ...                                         ...
# sFIS_04                                0.510954
# sFIS_05                                0.551277
# sFIS_06                                0.564506
# sFIS_07                                0.511498
# sFIS_09                                0.542587
#
#           ctx-lh-cuneus/ctx-lh-middletemporal  \
# 002MSVIS                             0.438663
# 003MSVIS                             0.437115
# 004MSVIS                             0.495635
# 005MSVIS                             0.470048
# 010MSVIS                             0.480289
# ...                                       ...
# sFIS_04                              0.523408
# sFIS_05                              0.563930
# sFIS_06                              0.575095
# sFIS_07                              0.522041
# sFIS_09                              0.563418
#
#           ctx-lh-cuneus/ctx-lh-superiortemporal  ctx-lh-cuneus/ctx-lh-insula  \
# 002MSVIS                               0.449761                     0.452155
# 003MSVIS                               0.439072                     0.467706
# 004MSVIS                               0.494340                     0.529751
# 005MSVIS                               0.474063                     0.496681
# 010MSVIS                               0.480951                     0.506304
# ...                                         ...                          ...
# sFIS_04                                0.526900                     0.536187
# sFIS_05                                0.553221                     0.568623
# sFIS_06                                0.576159                     0.574720
# sFIS_07                                0.532287                     0.542792
# sFIS_09                                0.578927                     0.586152
#
#           ctx-lh-cuneus/Left-Thalamus-Proper  ctx-lh-cuneus/Left-Putamen  ...  \
# 002MSVIS                            0.427175                    0.461376  ...
# 003MSVIS                            0.431561                    0.473701  ...
# 004MSVIS                            0.459846                    0.520597  ...
# 005MSVIS                            0.490678                    0.483483  ...
# 010MSVIS                            0.460790                    0.497279  ...
# ...                                      ...                         ...  ...
# sFIS_04                             0.527307                    0.529803  ...
# sFIS_05                             0.521056                    0.559675  ...
# sFIS_06                             0.554926                    0.579100  ...
# sFIS_07                             0.514955                    0.537732  ...
# sFIS_09                             0.540903                    0.577817  ...
#
#           ctx-rh-paracentral/ctx-rh-posteriorcingulate  \
# 002MSVIS                                      0.373892
# 003MSVIS                                      0.387480
# 004MSVIS                                      0.395231
# 005MSVIS                                      0.405315
# 010MSVIS                                      0.385139
# ...                                                ...
# sFIS_04                                       0.425312
# sFIS_05                                       0.451312
# sFIS_06                                       0.512380
# sFIS_07                                       0.440810
# sFIS_09                                       0.473371
#
#           ctx-rh-pericalcarine/ctx-rh-superiortemporal  \
# 002MSVIS                                      0.459131
# 003MSVIS                                      0.484542
# 004MSVIS                                      0.532746
# 005MSVIS                                      0.519941
# 010MSVIS                                      0.455612
# ...                                                ...
# sFIS_04                                       0.535670
# sFIS_05                                       0.548972
# sFIS_06                                       0.569164
# sFIS_07                                       0.533881
# sFIS_09                                       0.562764
#
#           ctx-rh-pericalcarine/ctx-rh-insula  \
# 002MSVIS                            0.481303
# 003MSVIS                            0.509567
# 004MSVIS                            0.569240
# 005MSVIS                            0.553714
# 010MSVIS                            0.478483
# ...                                      ...
# sFIS_04                             0.567077
# sFIS_05                             0.570932
# sFIS_06                             0.582518
# sFIS_07                             0.539735
# sFIS_09                             0.593815
#
#           ctx-rh-postcentral/ctx-rh-posteriorcingulate  \
# 002MSVIS                                      0.422469
# 003MSVIS                                      0.381282
# 004MSVIS                                      0.441564
# 005MSVIS                                      0.451796
# 010MSVIS                                      0.421267
# ...                                                ...
# sFIS_04                                       0.457714
# sFIS_05                                       0.484548
# sFIS_06                                       0.523785
# sFIS_07                                       0.473456
# sFIS_09                                       0.520070
#
#           ctx-rh-posteriorcingulate/ctx-rh-precentral    age  sex     dd  \
# 002MSVIS                                     0.456810  51.53    1  22.18
# 003MSVIS                                     0.379665  58.06    0   9.57
# 004MSVIS                                     0.468934  60.78    1   6.79
# 005MSVIS                                     0.460124  37.95    0   8.45
# 010MSVIS                                     0.433123  52.64    0   9.05
# ...                                               ...    ...  ...    ...
# sFIS_04                                      0.451951  32.98    1  -1.00
# sFIS_05                                      0.475987  23.76    0  -1.00
# sFIS_06                                      0.527624  24.11    0  -1.00
# sFIS_07                                      0.483277  23.98    0  -1.00
# sFIS_09                                      0.504627  23.46    0  -1.00
#
#           edss  controls_ms
# 002MSVIS   7.5            1
# 003MSVIS   6.0            1
# 004MSVIS   3.0            1
# 005MSVIS   1.5            1
# 010MSVIS   2.0            1
# ...        ...          ...
# sFIS_04    0.0            0
# sFIS_05    0.0            0
# sFIS_06    0.0            0
# sFIS_07    0.0            0
# sFIS_09    0.0            0
#
# [165 rows x 191 columns]

# %%
# Out:
#           ctx-lh-caudalanteriorcingulate/Left-Caudate  \
# 002MSVIS                                     0.384047
# 003MSVIS                                     0.307005
# 004MSVIS                                     0.353240
# 005MSVIS                                     0.392988
# 010MSVIS                                     0.381108
# ...                                               ...
# sFIS_04                                           NaN
# sFIS_05                                           NaN
# sFIS_06                                           NaN
# sFIS_07                                           NaN
# sFIS_09                                           NaN
#
#           ctx-lh-caudalanteriorcingulate/ctx-rh-caudalmiddlefrontal  \
# 002MSVIS                                           0.489209
# 003MSVIS                                           0.440887
# 004MSVIS                                           0.539666
# 005MSVIS                                           0.480349
# 010MSVIS                                           0.464374
# ...                                                     ...
# sFIS_04                                                 NaN
# sFIS_05                                                 NaN
# sFIS_06                                                 NaN
# sFIS_07                                                 NaN
# sFIS_09                                                 NaN
#
#           ctx-lh-caudalanteriorcingulate/ctx-rh-rostralmiddlefrontal  \
# 002MSVIS                                           0.446729
# 003MSVIS                                           0.426359
# 004MSVIS                                           0.518063
# 005MSVIS                                           0.455465
# 010MSVIS                                           0.459644
# ...                                                     ...
# sFIS_04                                                 NaN
# sFIS_05                                                 NaN
# sFIS_06                                                 NaN
# sFIS_07                                                 NaN
# sFIS_09                                                 NaN
#
#           ctx-lh-caudalmiddlefrontal/ctx-rh-paracentral  \
# 002MSVIS                                       0.524677
# 003MSVIS                                       0.475393
# 004MSVIS                                       0.552257
# 005MSVIS                                       0.550401
# 010MSVIS                                       0.472687
# ...                                                 ...
# sFIS_04                                             NaN
# sFIS_05                                             NaN
# sFIS_06                                             NaN
# sFIS_07                                             NaN
# sFIS_09                                             NaN
#
#           ctx-lh-cuneus/ctx-lh-inferiortemporal  \
# 002MSVIS                               0.426897
# 003MSVIS                               0.433756
# 004MSVIS                               0.485544
# 005MSVIS                               0.462872
# 010MSVIS                               0.473701
# ...                                         ...
# sFIS_04                                     NaN
# sFIS_05                                     NaN
# sFIS_06                                     NaN
# sFIS_07                                     NaN
# sFIS_09                                     NaN
#
#           ctx-lh-cuneus/ctx-lh-middletemporal  \
# 002MSVIS                             0.438663
# 003MSVIS                             0.437115
# 004MSVIS                             0.495635
# 005MSVIS                             0.470048
# 010MSVIS                             0.480289
# ...                                       ...
# sFIS_04                                   NaN
# sFIS_05                                   NaN
# sFIS_06                                   NaN
# sFIS_07                                   NaN
# sFIS_09                                   NaN
#
#           ctx-lh-cuneus/ctx-lh-superiortemporal  ctx-lh-cuneus/ctx-lh-insula  \
# 002MSVIS                               0.449761                     0.452155
# 003MSVIS                               0.439072                     0.467706
# 004MSVIS                               0.494340                     0.529751
# 005MSVIS                               0.474063                     0.496681
# 010MSVIS                               0.480951                     0.506304
# ...                                         ...                          ...
# sFIS_04                                     NaN                          NaN
# sFIS_05                                     NaN                          NaN
# sFIS_06                                     NaN                          NaN
# sFIS_07                                     NaN                          NaN
# sFIS_09                                     NaN                          NaN
#
#           ctx-lh-cuneus/Left-Thalamus-Proper  ctx-lh-cuneus/Left-Putamen  ...  \
# 002MSVIS                            0.427175                    0.461376  ...
# 003MSVIS                            0.431561                    0.473701  ...
# 004MSVIS                            0.459846                    0.520597  ...
# 005MSVIS                            0.490678                    0.483483  ...
# 010MSVIS                            0.460790                    0.497279  ...
# ...                                      ...                         ...  ...
# sFIS_04                                  NaN                         NaN  ...
# sFIS_05                                  NaN                         NaN  ...
# sFIS_06                                  NaN                         NaN  ...
# sFIS_07                                  NaN                         NaN  ...
# sFIS_09                                  NaN                         NaN  ...
#
#           ctx-rh-paracentral/ctx-rh-posteriorcingulate  \
# 002MSVIS                                      0.373892
# 003MSVIS                                      0.387480
# 004MSVIS                                      0.395231
# 005MSVIS                                      0.405315
# 010MSVIS                                      0.385139
# ...                                                ...
# sFIS_04                                            NaN
# sFIS_05                                            NaN
# sFIS_06                                            NaN
# sFIS_07                                            NaN
# sFIS_09                                            NaN
#
#           ctx-rh-pericalcarine/ctx-rh-superiortemporal  \
# 002MSVIS                                      0.459131
# 003MSVIS                                      0.484542
# 004MSVIS                                      0.532746
# 005MSVIS                                      0.519941
# 010MSVIS                                      0.455612
# ...                                                ...
# sFIS_04                                            NaN
# sFIS_05                                            NaN
# sFIS_06                                            NaN
# sFIS_07                                            NaN
# sFIS_09                                            NaN
#
#           ctx-rh-pericalcarine/ctx-rh-insula  \
# 002MSVIS                            0.481303
# 003MSVIS                            0.509567
# 004MSVIS                            0.569240
# 005MSVIS                            0.553714
# 010MSVIS                            0.478483
# ...                                      ...
# sFIS_04                                  NaN
# sFIS_05                                  NaN
# sFIS_06                                  NaN
# sFIS_07                                  NaN
# sFIS_09                                  NaN
#
#           ctx-rh-postcentral/ctx-rh-posteriorcingulate  \
# 002MSVIS                                      0.422469
# 003MSVIS                                      0.381282
# 004MSVIS                                      0.441564
# 005MSVIS                                      0.451796
# 010MSVIS                                      0.421267
# ...                                                ...
# sFIS_04                                            NaN
# sFIS_05                                            NaN
# sFIS_06                                            NaN
# sFIS_07                                            NaN
# sFIS_09                                            NaN
#
#           ctx-rh-posteriorcingulate/ctx-rh-precentral    age  sex   dd  edss  \
# 002MSVIS                                     0.456810    NaN  NaN  NaN   NaN
# 003MSVIS                                     0.379665    NaN  NaN  NaN   NaN
# 004MSVIS                                     0.468934    NaN  NaN  NaN   NaN
# 005MSVIS                                     0.460124    NaN  NaN  NaN   NaN
# 010MSVIS                                     0.433123    NaN  NaN  NaN   NaN
# ...                                               ...    ...  ...  ...   ...
# sFIS_04                                           NaN  32.98  1.0 -1.0   0.0
# sFIS_05                                           NaN  23.76  0.0 -1.0   0.0
# sFIS_06                                           NaN  24.11  0.0 -1.0   0.0
# sFIS_07                                           NaN  23.98  0.0 -1.0   0.0
# sFIS_09                                           NaN  23.46  0.0 -1.0   0.0
#
#           controls_ms
# 002MSVIS          NaN
# 003MSVIS          NaN
# 004MSVIS          NaN
# 005MSVIS          NaN
# 010MSVIS          NaN
# ...               ...
# sFIS_04           0.0
# sFIS_05           0.0
# sFIS_06           0.0
# sFIS_07           0.0
# sFIS_09           0.0
#
# [330 rows x 191 columns]
